# %%
#imports
import torch
from IPython.display import Image  # for displaying images
import os 
import random
import shutil
from sklearn.model_selection import train_test_split
import xml.etree.ElementTree as ET
from xml.dom import minidom
from tqdm import tqdm
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt
import glob
import tensorflow as tf
import datetime

random.seed(108)

# %%
# !git clone https://github.com/WongKinYiu/yolov7
# %cd yolov7
# !pip install -r requirements.txt
# Out:
# d:\CursPaper\yolov7
# Cloning into 'yolov7'...
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 4)) (3.7.1)
# Requirement already satisfied: numpy<1.24.0,>=1.18.5 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 5)) (1.23.5)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 6)) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 7)) (9.3.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 8)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 9)) (2.28.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 10)) (1.10.1)
# Requirement already satisfied: torch!=1.12.0,>=1.7.0 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 11)) (2.0.0+cu117)
# Requirement already satisfied: torchvision!=0.13.0,>=0.8.1 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 12)) (0.15.1+cu117)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 13)) (4.65.0)
# Collecting protobuf<4.21.3
#   Using cached protobuf-4.21.2-cp310-abi3-win_amd64.whl (524 kB)
# Requirement already satisfied: tensorboard>=2.4.1 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 17)) (2.12.3)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 21)) (2.0.1)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 22)) (0.12.2)
# Requirement already satisfied: ipython in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 34)) (8.11.0)
# Requirement already satisfied: psutil in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 35)) (5.9.4)
# Collecting thop
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (4.39.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2022.12.7)
# Requirement already satisfied: filelock in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (4.4.0)
# Requirement already satisfied: sympy in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (1.11.1)
# Requirement already satisfied: networkx in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (3.0)
# Requirement already satisfied: jinja2 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (3.1.2)
# Requirement already satisfied: colorama in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.41.0->-r requirements.txt (line 13)) (0.4.6)
# Requirement already satisfied: absl-py>=0.4 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (3.4.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.1008.0_x64__qbz5n2kfra8p0\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (65.5.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (2.3.3)
# Requirement already satisfied: wheel>=0.26 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 17)) (0.40.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.1.4->-r requirements.txt (line 21)) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.1.4->-r requirements.txt (line 21)) (2023.3)
# Requirement already satisfied: backcall in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->-r requirements.txt (line 34)) (0.2.0)
# Requirement already satisfied: decorator in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->-r requirements.txt (line 34)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->-r requirements.txt (line 34)) (0.18.2)
# Requirement already satisfied: matplotlib-inline in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->-r requirements.txt (line 34)) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->-r requirements.txt (line 34)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->-r requirements.txt (line 34)) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->-r requirements.txt (line 34)) (2.14.0)
# Requirement already satisfied: stack-data in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->-r requirements.txt (line 34)) (0.6.2)
# Requirement already satisfied: traitlets>=5 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->-r requirements.txt (line 34)) (5.9.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 17)) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 17)) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 17)) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 17)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.4.1->-r requirements.txt (line 17)) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jedi>=0.16->ipython->-r requirements.txt (line 34)) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->-r requirements.txt (line 34)) (0.2.6)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->-r requirements.txt (line 17)) (2.1.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack-data->ipython->-r requirements.txt (line 34)) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack-data->ipython->-r requirements.txt (line 34)) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack-data->ipython->-r requirements.txt (line 34)) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy->torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (1.2.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 17)) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.4.1->-r requirements.txt (line 17)) (3.2.2)
# Installing collected packages: protobuf, thop
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.22.4
#     Uninstalling protobuf-4.22.4:
#       Successfully uninstalled protobuf-4.22.4
# ERROR: Could not install packages due to an OSError: [WinError 5] Отказано в доступе: 'C:\\Users\\denzi\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\site-packages\\google\\~-pb\\_message.pyd'
# Check the permissions.
#
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: C:\Users\denzi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="mRs9vg8hQcE37xjAudq2")
project = rf.workspace("saratov-state-uni").project("number-detection-s85cr")
dataset = project.version(3).download("yolov7")
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.12.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 4.21.2 which is incompatible.
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: C:\Users\denzi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting roboflow
#   Downloading roboflow-1.0.8-py3-none-any.whl (56 kB)
#      -------------------------------------- 56.3/56.3 kB 582.9 kB/s eta 0:00:00
# Requirement already satisfied: certifi==2022.12.7 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (2022.12.7)
# Collecting chardet==4.0.0
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      -------------------------------------- 178.7/178.7 kB 2.1 MB/s eta 0:00:00
# Collecting cycler==0.10.0
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.8/58.8 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (1.23.5)
# Requirement already satisfied: opencv-python>=4.1.2 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (9.3.0)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ---------------------------------------- 67.8/67.8 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (2.8.2)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (2.28.1)
# Requirement already satisfied: six in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (1.26.13)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (4.65.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (6.0)
# Collecting requests-toolbelt
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ---------------------------------------- 54.5/54.5 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->roboflow) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->roboflow) (4.39.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->roboflow) (23.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->roboflow) (2.1.1)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py): started
#   Building wheel for wget (setup.py): finished with status 'done'
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9681 sha256=cac04d8f6c4fda67babf3757700de38de0abd0311f84e9f5b32be20055b49991
#   Stored in directory: c:\users\denzi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\f0\e4\9c\b3ed593784fe0147db216173b4046fce93fae7130b29e4464e
# Successfully built wget
# Installing collected packages: wget, python-dotenv, pyparsing, idna, cycler, chardet, requests-toolbelt, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
# Successfully installed chardet-4.0.0 cycler-0.10.0 idna-2.10 pyparsing-2.4.7 python-dotenv-1.0.0 requests-toolbelt-1.0.0 roboflow-1.0.8 wget-3.2
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in number-detection-3 to yolov7pytorch: 100% [51345076 / 51345076] bytes
# Extracting Dataset Version Zip to number-detection-3 in yolov7pytorch:: 100%|██████████| 1388/1388 [00:00<00:00, 2556.17it/s]

# %%
# !wandb login e478cc6c0a4343a9912bfe3a45254bbf4c6139c1
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\denzi/.netrc

# %%
# %%writefile cfg/training/yolov7_bus.yaml
# # parameters
# nc: 1  # number of classes
# depth_multiple: 1.0  # model depth multiple
# width_multiple: 1.0  # layer channel multiple
#
# # anchors
# anchors:
#   - [12,16, 19,36, 40,28]  # P3/8
#   - [36,75, 76,55, 72,146]  # P4/16
#   - [142,110, 192,243, 459,401]  # P5/32
#
# # yolov7 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [32, 3, 1]],  # 0
#
#   [-1, 1, Conv, [64, 3, 2]],  # 1-P1/2
#   [-1, 1, Conv, [64, 3, 1]],
#
#   [-1, 1, Conv, [128, 3, 2]],  # 3-P2/4
#   [-1, 1, Conv, [64, 1, 1]],
#   [-2, 1, Conv, [64, 1, 1]],
#   [-1, 1, Conv, [64, 3, 1]],
#   [-1, 1, Conv, [64, 3, 1]],
#   [-1, 1, Conv, [64, 3, 1]],
#   [-1, 1, Conv, [64, 3, 1]],
#   [[-1, -3, -5, -6], 1, Concat, [1]],
#   [-1, 1, Conv, [256, 1, 1]],  # 11
#
#   [-1, 1, MP, []],
#   [-1, 1, Conv, [128, 1, 1]],
#   [-3, 1, Conv, [128, 1, 1]],
#   [-1, 1, Conv, [128, 3, 2]],
#   [[-1, -3], 1, Concat, [1]],  # 16-P3/8
#   [-1, 1, Conv, [128, 1, 1]],
#   [-2, 1, Conv, [128, 1, 1]],
#   [-1, 1, Conv, [128, 3, 1]],
#   [-1, 1, Conv, [128, 3, 1]],
#   [-1, 1, Conv, [128, 3, 1]],
#   [-1, 1, Conv, [128, 3, 1]],
#   [[-1, -3, -5, -6], 1, Concat, [1]],
#   [-1, 1, Conv, [512, 1, 1]],  # 24
#
#   [-1, 1, MP, []],
#   [-1, 1, Conv, [256, 1, 1]],
#   [-3, 1, Conv, [256, 1, 1]],
#   [-1, 1, Conv, [256, 3, 2]],
#   [[-1, -3], 1, Concat, [1]],  # 29-P4/16
#   [-1, 1, Conv, [256, 1, 1]],
#   [-2, 1, Conv, [256, 1, 1]],
#   [-1, 1, Conv, [256, 3, 1]],
#   [-1, 1, Conv, [256, 3, 1]],
#   [-1, 1, Conv, [256, 3, 1]],
#   [-1, 1, Conv, [256, 3, 1]],
#   [[-1, -3, -5, -6], 1, Concat, [1]],
#   [-1, 1, Conv, [1024, 1, 1]],  # 37
#
#   [-1, 1, MP, []],
#   [-1, 1, Conv, [512, 1, 1]],
#   [-3, 1, Conv, [512, 1, 1]],
#   [-1, 1, Conv, [512, 3, 2]],
#   [[-1, -3], 1, Concat, [1]],  # 42-P5/32
#   [-1, 1, Conv, [256, 1, 1]],
#   [-2, 1, Conv, [256, 1, 1]],
#   [-1, 1, Conv, [256, 3, 1]],
#   [-1, 1, Conv, [256, 3, 1]],
#   [-1, 1, Conv, [256, 3, 1]],
#   [-1, 1, Conv, [256, 3, 1]],
#   [[-1, -3, -5, -6], 1, Concat, [1]],
#   [-1, 1, Conv, [1024, 1, 1]],  # 50
#   ]
#
# # yolov7 head
# head:
#   [[-1, 1, SPPCSPC, [512]], # 51
#
#   [-1, 1, Conv, [256, 1, 1]],
#   [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#   [37, 1, Conv, [256, 1, 1]], # route backbone P4
#   [[-1, -2], 1, Concat, [1]],
#
#   [-1, 1, Conv, [256, 1, 1]],
#   [-2, 1, Conv, [256, 1, 1]],
#   [-1, 1, Conv, [128, 3, 1]],
#   [-1, 1, Conv, [128, 3, 1]],
#   [-1, 1, Conv, [128, 3, 1]],
#   [-1, 1, Conv, [128, 3, 1]],
#   [[-1, -2, -3, -4, -5, -6], 1, Concat, [1]],
#   [-1, 1, Conv, [256, 1, 1]], # 63
#
#   [-1, 1, Conv, [128, 1, 1]],
#   [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#   [24, 1, Conv, [128, 1, 1]], # route backbone P3
#   [[-1, -2], 1, Concat, [1]],
#
#   [-1, 1, Conv, [128, 1, 1]],
#   [-2, 1, Conv, [128, 1, 1]],
#   [-1, 1, Conv, [64, 3, 1]],
#   [-1, 1, Conv, [64, 3, 1]],
#   [-1, 1, Conv, [64, 3, 1]],
#   [-1, 1, Conv, [64, 3, 1]],
#   [[-1, -2, -3, -4, -5, -6], 1, Concat, [1]],
#   [-1, 1, Conv, [128, 1, 1]], # 75
#
#   [-1, 1, MP, []],
#   [-1, 1, Conv, [128, 1, 1]],
#   [-3, 1, Conv, [128, 1, 1]],
#   [-1, 1, Conv, [128, 3, 2]],
#   [[-1, -3, 63], 1, Concat, [1]],
#
#   [-1, 1, Conv, [256, 1, 1]],
#   [-2, 1, Conv, [256, 1, 1]],
#   [-1, 1, Conv, [128, 3, 1]],
#   [-1, 1, Conv, [128, 3, 1]],
#   [-1, 1, Conv, [128, 3, 1]],
#   [-1, 1, Conv, [128, 3, 1]],
#   [[-1, -2, -3, -4, -5, -6], 1, Concat, [1]],
#   [-1, 1, Conv, [256, 1, 1]], # 88
#
#   [-1, 1, MP, []],
#   [-1, 1, Conv, [256, 1, 1]],
#   [-3, 1, Conv, [256, 1, 1]],
#   [-1, 1, Conv, [256, 3, 2]],
#   [[-1, -3, 51], 1, Concat, [1]],
#
#   [-1, 1, Conv, [512, 1, 1]],
#   [-2, 1, Conv, [512, 1, 1]],
#   [-1, 1, Conv, [256, 3, 1]],
#   [-1, 1, Conv, [256, 3, 1]],
#   [-1, 1, Conv, [256, 3, 1]],
#   [-1, 1, Conv, [256, 3, 1]],
#   [[-1, -2, -3, -4, -5, -6], 1, Concat, [1]],
#   [-1, 1, Conv, [512, 1, 1]], # 101
#
#   [75, 1,   , [256, 3, 1]],
#   [88, 1, RepConv, [512, 3, 1]],
#   [101, 1, RepConv, [1024, 3, 1]],
#
#   [[102,103,104], 1, IDetect, [nc, anchors]],   # Detect(P3, P4, P5)
#   ]
# Out:
# Writing cfg/training/yolov7_bus.yaml

# %%
import pytorch
# !pip show torch

# %%
# %cd yolov7/
# !python train.py --epochs 100 --batch-size 8 --data number-detection-3/data.yaml \
--img 640 640 --cfg cfg/training/yolov7_bus.yaml --weights 'yolov7_training.pt' \
--name yolov7_bus_res --hyp data/hyp.scratch.custom.yaml
# Out:
# [WinError 2] Не удается найти указанный файл: 'yolov7/'
# d:\CursPaper\yolov7
# Traceback (most recent call last):
#   File "d:\CursPaper\yolov7\train.py", line 12, in <module>
#     import torch.distributed as dist
#   File "C:\Users\denzi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\__init__.py", line 122, in <module>
#     raise err
# OSError: [WinError 1455] Файл подкачки слишком мал для завершения операции. Error loading "C:\Users\denzi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\lib\cufft64_10.dll" or one of its dependencies.
